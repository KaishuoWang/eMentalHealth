# %% [markdown]
# ##NLTK

# %%
# importing the nltk suite
import nltk

# importing jaccard distance
# and ngrams from nltk.util
from nltk.metrics.distance import jaccard_distance
from nltk.util import ngrams

# %%
# Downloading and importing
# package 'words' from nltk corpus
nltk.download('words')
from nltk.corpus import words


correct_words = words.words()
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
# list of incorrect spellings
# that need to be corrected
incorrect_words=['Deliriuum', 'azmaing', 'intelliengt']

# loop for finding correct spellings
# based on jaccard distance
# and printing the correct word
for word in incorrect_words:
	temp = [(jaccard_distance(set(ngrams(word, 2)),
							set(ngrams(w, 2))),w)
			for w in correct_words if w[0]==word[0]]
	print(sorted(temp, key = lambda val:val[0])[0][1])
# Out:
# Dendrium
# amazing
# intelligent

# %% [markdown]
# ##TextBlob

# %%
from textblob import TextBlob

text = "She had Bulimmia"
TextBlob(text).correct()
# Out:
# TextBlob("The had Bulimmia")

# %% [markdown]
# ##Autocorrect

# %%
# !pip install autocorrect
from autocorrect import Speller

spell = Speller()
text4 = "She had fits of deliriuum."
spell(text4)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 622.8/622.8 kB 11.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for autocorrect: filename=autocorrect-2.6.1-py3-none-any.whl size=622363 sha256=c5dd47ed5d4092272c4f99e31ec129c0fc9530cd651f0217d5246c64a4ab28a0
#   Stored in directory: /root/.cache/pip/wheels/b5/7b/6d/b76b29ce11ff8e2521c8c7dd0e5bfee4fb1789d76193124343
# Successfully built autocorrect
# ...
# 'She had fits of deliriuum.'

# %% [markdown]
# ##Pyspellchecker

# %%
# !pip install pyspellchecker
from spellchecker import SpellChecker

spell2 = SpellChecker()
text6 = "She had fits of deliriuum."

#Get the misspelled text
misspelled_text6 = spell2.unknown(text6)
misspelled_text6
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# {' ', 'd', 'f', 'h', 'l', 'm', 'r', 's', 't'}

# %%
#Correct the misspelled words
for word in misspelled_text6:
    print(spell2.correction(word))
    #Get a list of 'likely' options
    print(spell2.candidates(word))
    pass
