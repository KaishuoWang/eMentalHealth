# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !cp /content/gdrive/MyDrive/CSI6900/pre_processing.py /content
# Out:
# Mounted at /content/gdrive

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import random
import torch
import pandas as pd
import numpy as np
import random
from ast import literal_eval
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import torch

nltk.download('punkt')
nltk.download('stopwords')

# colab
# KW
#DATA_PATH = '/content/gdrive/MyDrive/CSI6900/'

# FZ
DATA_PATH = 'gdrive/MyDrive/CSI6900/'

device = torch.device("mps" if getattr(torch,'has_mps',False) else "cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# device(type='cpu')

# %% [markdown]
# ## Load data

# %%
infoSheet = pd.read_csv(DATA_PATH + 'data/openai_embedding/infoSheet_name_abstract.csv')
infoSheet['embedding'] = infoSheet['embedding'].apply(literal_eval)
print(infoSheet.isnull().sum())
print('Length: ', len(infoSheet.index))
infoSheet.head(10)
# Out:
# ID                       0
# name_en                  0
# name_fr                 87
# abstract_en              0
# abstract_fr             89
# description_en           0
# description_fr          87
# taxonomy heading ids     0
# embedding                0
# dtype: int64
# Length:  230
#       ID                                            name_en  \
# 0   8920                        Abuse and Domestic Violence
# 1  69660  ADHD in Children, Youth and Adults: Informatio...
# 2  20505                    ADHD: Managing ADHD Medications
# 3   8917  Alcohol and Substance Use Problems in Children...
# 4   8909         Alcohol: Cutting Back or Quitting Drinking
# 5  61003  Alcohol Use Disorder in Adults: Information fo...
# 6  18393  Alcohol Use Disorder in Youth: Information for...
# 7  24390  Alzheimer's Dementia: Information for Primary ...
# 8  11564                                              Anger
# 9  26975     Anorexia Nervosa: Information for Primary Care
#
#                                              name_fr  \
# 0                 Maltraitance et violence familiale
# 1                                                NaN
# 2         TDAH: Gestion des médicaments pour le TDAH
# 3  Problèmes de l’alcoolisme et la toxicomanie ch...
# 4          Problèmes liés à la consommation d'alcool
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                          La colère
# 9                                                NaN
#
#                                          abstract_en  \
# 0  Abuse is behaviour used to intimidate, isolate...
# 1  Attention deficit hyperactivity disorder (ADHD...
# 2  Although ADHD medications may be helpful for s...
# 3  Many children/youth experiment with alcohol an...
# 4  Drinking alcohol is an accepted practice in ma...
# 5  Alcohol use problems are common in primary car...
# 6  Many youth will experiment with alcohol and su...
# 7  Alzheimer’s is the most common form of dementi...
# 8  Anger is a normal emotion that we get when we ...
# 9  Anorexia nervosa is a common eating disorder a...
#
#                                          abstract_fr  \
# 0  La maltraitance est un comportement visant à i...
# 1                                                NaN
# 2  Bien que les médicaments du TDAH peuvent être ...
# 3  Nombreux sont les enfants et les jeunes qui fo...
# 4  La consommation d'alcool est une pratique acce...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  La colère est une émotion normale que nous res...
# 9                                                NaN
#
#                                       description_en  \
# 0  \r\n\tWhat is Abuse and Domestic Violence?\r\n...
# 1  \r\n\tAbbreviations\r\n\r\n\tADHD, attention-d...
# 2  \r\n\tGeneral Considerations\r\n\r\n\t\r\n\t\t...
# 3  \r\n\tDavid's Story\r\n\r\n\tUp until this sch...
# 4  \r\n\tIntroduction\r\n\r\n\tMany people who dr...
# 5  \r\n\tEpidemiology\r\n\r\n\tPrevalence\r\n\r\n...
# 6  Epidemiology\r\n\r\n\t\r\n\t\t10% of the&nbsp;...
# 7  \r\n\tCase\r\n\r\n\t\r\n\t\tYour 80 year old p...
# 8  \r\n\tDoes any of this sound like you?\r\n\r\n...
# 9  \r\n\tCase\r\nIdentifying data&nbsp;32-yo fema...
#
#                                       description_fr  \
# 0  \r\n\tQu&#39;est-ce que la maltraitance et la ...
# 1                                                NaN
# 2  \r\n\tObservations générales\r\n\r\n\t\r\n\t\t...
# 3  \r\n\tL’histoire de David\r\n\r\n\tJusqu’à cet...
# 4  \r\n\tIntroduction\r\n\r\n\tNombreuses sont le...
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8  \r\n\tEst-ce que cela trouve un &eacute;cho ch...
# 9                                                NaN
#
#            taxonomy heading ids  \
# 0  0,219,58,8,7,6,50,9,36,54,37
# 1                          0,13
# 2                          0,13
# 3                          0,12
# 4                          0,12
# 5                      0,12,266
# 6                      0,12,266
# 7                          0,79
# 8            0,14,50,54,9,36,37
# 9                          0,22
#
#                                            embedding
# 0  [-0.006836807355284691, -1.2969143426744267e-0...
# 1  [6.297678191913292e-05, 0.005104047246277332, ...
# 2  [-0.007076850160956383, -0.0020307896193116903...
# 3  [-0.0038117102812975645, -0.008029664866626263...
# 4  [-0.010912169702351093, 0.0006169816479086876,...
# 5  [-0.0002503542636986822, 0.0016840933822095394...
# 6  [-0.007133564446121454, -0.0029860695358365774...
# 7  [-0.0032352525740861893, 0.0039140209555625916...
# 8  [-0.0030424355063587427, 0.006882417947053909,...
# 9  [-3.332154960844491e-07, -0.000195899716345593...

# %%
taxonomy = pd.read_csv(DATA_PATH + 'data/openai_embedding/taxonomy_name_description.csv')
taxonomy['embedding'] = taxonomy['embedding'].apply(literal_eval)
# Drop rows where 'abstract_en' is NaN
taxonomy.dropna(subset=['description'], inplace=True)
taxonomy.reset_index(drop=True, inplace=True)
print(taxonomy.isnull().sum())
print('Length: ', len(taxonomy.index))
taxonomy.head(10)
# Out:
# id              0
# name            0
# description     0
# translations    0
# embedding       0
# dtype: int64
# Length:  192
#    id                                               name  \
# 0   1                                               Root
# 1   2                        All Mental Health Resources
# 2   3                               Crisis and Emergency
# 3   4  System Navigation, including Information and R...
# 4   5  Child Welfare including Children's Aid Society...
# 5   6                      Emergency Shelter and Housing
# 6   7                      Hospital Emergency Department
# 7   8  Crisis Lines including Telephone, Online and Chat
# 8   9                                      Psychiatrists
# 9  10            A-Z Mental Health Conditions and Topics
#
#                                          description  \
# 0                                               Root
# 1  The listings of mental health resources includ...
# 2  Refers to all programs that provide immediate ...
# 3  Are you looking for help, but dont know where ...
# 4  The child welfare / child protection system is...
# 5  There are various shelters that people can use...
# 6  Is there an emergency such as medical or menta...
# 7  Are you in a crisis? Crisis lines offer free, ...
# 8  Psychiatrists are medical doctors who have rec...
# 9  Alphabetical list of mental health topics and ...
#
#                                         translations  \
# 0  {"name":{"en":"Root","fr":null},"description":...
# 1  {"name":{"en":"All Mental Health Resources","f...
# 2  {"name":{"en":"Crisis and Emergency","fr":"Res...
# 3  {"name":{"en":"System Navigation, including In...
# 4  {"name":{"en":"Child Welfare including Childre...
# 5  {"name":{"en":"Emergency Shelter and Housing",...
# 6  {"name":{"en":"Hospital Emergency Department",...
# 7  {"name":{"en":"Crisis Lines including Telephon...
# 8  {"name":{"en":"Psychiatrists","fr":"Psychiatre...
# 9  {"name":{"en":"A-Z Mental Health Conditions an...
#
#                                            embedding
# 0  [-0.01242552325129509, 0.0049454341642558575, ...
# 1  [-0.003916683606803417, 0.0043426863849163055,...
# 2  [-0.0016540151555091143, 0.004231865983456373,...
# 3  [-0.0052290805615484715, 0.001998607302084565,...
# 4  [-0.0017937872326001525, 0.002536701038479805,...
# 5  [-0.003927853424102068, 0.005480578169226646, ...
# 6  [-0.01046136673539877, 0.001888505183160305, -...
# 7  [-0.006740534212440252, -0.004541291855275631,...
# 8  [0.00967669952660799, 0.0008635374833829701, -...
# 9  [-0.010088824667036533, 0.0018147194059565663,...

# %% [markdown]
# ## Pre-processing

# %%
# Remove stop words and stemming
stop_words = set(stopwords.words('english'))
def preprocessing(sentence):
    stemmer = PorterStemmer()
    text_tokens = word_tokenize(sentence)
    tokens_without_sw = [word for word in text_tokens if not word.lower() in stop_words]
    tokens_stemmed = [stemmer.stem(word) for word in tokens_without_sw]
    return tokens_stemmed

# %% [markdown]
# ## TF-IDF

# %%
# Randomly choose 10 infoSheets
search_term_indices = [random.randint(0, len(infoSheet.index)) for i in range(10)]
search_term_indices = [113, 10, 124, 39, 88, 23, 69, 13, 179, 218]

# %%
# Tokenize docs
taxonomy_description = taxonomy['description'].tolist()
taxonomy_name = taxonomy['name'].tolist()

tokenized_taxonomy = []
tokenized_taxonomy_join = []
for i in range(len(taxonomy_name)):
    tokenized_taxonomy.append(preprocessing(taxonomy_name[i] + ': ' + taxonomy_description[i]))

for j in range(len(tokenized_taxonomy)):
    taxonomy_join = " ".join(tokenized_taxonomy[j])
    tokenized_taxonomy_join.append(taxonomy_join)

# Tokenize queries
tokenized_infoSheet = []
tokenized_infoSheet_join = []
for each in search_term_indices:
    if infoSheet['taxonomy heading ids'][each] != '0':
        tokenized_infoSheet.append(preprocessing(infoSheet['name_en'][each] + ': ' + infoSheet['abstract_en'][each]))

for k in range(len(tokenized_infoSheet)):
    infoSheet_join = " ".join(tokenized_infoSheet[k])
    tokenized_infoSheet_join.append(infoSheet_join)

# %%
# Create an instance of the TfidfVectorizer
vectorizer = TfidfVectorizer()

# Fit the vectorizer to your corpus of documents and transform the documents into TF-IDF vectors
tfidf_matrix = vectorizer.fit_transform(tokenized_taxonomy_join)

# # Get the feature names (terms) corresponding to the columns of the TF-IDF matrix
# feature_names = vectorizer.get_feature_names_out()

# # Print the TF-IDF matrix
# #print(tfidf_matrix.toarray())

# # Print the TF-IDF values for each document and term
# for doc_index, doc in enumerate(tokenized_taxonomy):
#     print(f"TF-IDF values for document {doc_index+1}:")
#     for term_index, term in enumerate(feature_names):
#         tfidf_value = tfidf_matrix[doc_index, term_index]
#         if tfidf_value > 0:
#             print(f"{term}: {tfidf_value}")
#     print()

# %%
# Transform the query into a TF-IDF vector using the same vectorizer
query_vector = vectorizer.transform(tokenized_infoSheet_join)

# Calculate the cosine similarity between the query vector and all document vectors
cosine_similarities = cosine_similarity(query_vector, tfidf_matrix)

# # Get the indices of the documents sorted by their similarity to the query (in descending order)
# similarity_scores = cosine_similarities[0]
# sorted_indices = similarity_scores.argsort()[::-1]

# # Print the top-k most relevant documents
# topK = 100  # Number of top documents to retrieve
# for i in range(topK):
#     doc_index = sorted_indices[i]
#     relevance_score = similarity_scores[doc_index]
#     document = tokenized_taxonomy_join[doc_index]
#     print(f"Document {doc_index+1}:")
#     print(f"Relevance score: {relevance_score}")
#     print(f"Content: {document}")
#     print()

topK = 100
tfidf_score = []
for each in cosine_similarities:
    top_results = torch.topk(torch.tensor(each), topK)
    tfidf_score.append(top_results)

# %% [markdown]
# ## OpenAI Search
#
# Re-rank top 100 results retrivaled by TF-IDF

# %%
# !pip install openai
# Out:
# Collecting openai
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.6/73.6 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from openai) (3.8.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (1.3.1)
# Installing collected packages: openai
# Successfully installed openai-0.27.8

# %%
import openai
from openai.embeddings_utils import get_embedding, cosine_similarity

def takeFirst(elem):
    return elem[0]

def search(query_indices, doc_indices, topK=10):
    if topK > len(taxonomy):
        topK = len(taxonomy)

    result = []

    for i in range((len(query_indices))):
        query_embedding = infoSheet['embedding'][query_indices[i]]
        tmp = []
        for j in doc_indices[i]:
            doc_embedding = taxonomy['embedding'][j]
            tmp.append((cosine_similarity(doc_embedding, query_embedding), j))
        tmp.sort(key=takeFirst, reverse=True)
        result.append(tmp[:10])

    return result

doc_indices = []
for each in tfidf_score:
    doc_indices.append(each[1].tolist())

result = search(search_term_indices, doc_indices)

# %%
predictions = {'infoSheet_index': [], 'infoSheet_name': [], 'pred_taxonomy_index': [], 'pred_taxonomy_name': [], 'score': [], 'gold_taxonomy_index': []}
for q in range(len(result)):
    for (score, idx) in result[q]:
        predictions['infoSheet_index'].append(search_term_indices[q])
        predictions['infoSheet_name'].append(infoSheet['name_en'][search_term_indices[q]])
        predictions['pred_taxonomy_index'].append(idx+1)
        predictions['pred_taxonomy_name'].append(taxonomy['name'][idx])
        predictions['score'].append(score)
        predictions['gold_taxonomy_index'].append(infoSheet['taxonomy heading ids'][search_term_indices[q]].split(','))

predictions = pd.DataFrame(predictions)
predictions.head(10)
# Out:
#    infoSheet_index         infoSheet_name  pred_taxonomy_index  \
# 0              113  Learning Disabilities                   25
# 1              113  Learning Disabilities                  110
# 2              113  Learning Disabilities                   21
# 3              113  Learning Disabilities                   13
# 4              113  Learning Disabilities                   57
# 5              113  Learning Disabilities                   16
# 6              113  Learning Disabilities                   48
# 7              113  Learning Disabilities                   46
# 8              113  Learning Disabilities                   15
# 9              113  Learning Disabilities                  167
#
#                                   pred_taxonomy_name     score  \
# 0                                 Learning Disorders  0.907325
# 1                                  Asperger Syndrome  0.894902
# 2  Developmental, Intellectual Delay and Disabili...  0.880416
# 3             Attention Deficit Disorders (ADD/ADHD)  0.868375
# 4                              Physical Disabilities  0.865600
# 5                     Behaviour and Conduct Problems  0.860598
# 6                Obsessive Compulsive Disorder (OCD)  0.853025
# 7                 Auditory Processing Disorder (APD)  0.851302
# 8               Autism and Autism Spectrum Disorders  0.849179
# 9                               Somatoform Disorders  0.839468
#
#     gold_taxonomy_index
# 0  [0, 25, 98, 220, 36]
# 1  [0, 25, 98, 220, 36]
# 2  [0, 25, 98, 220, 36]
# 3  [0, 25, 98, 220, 36]
# 4  [0, 25, 98, 220, 36]
# 5  [0, 25, 98, 220, 36]
# 6  [0, 25, 98, 220, 36]
# 7  [0, 25, 98, 220, 36]
# 8  [0, 25, 98, 220, 36]
# 9  [0, 25, 98, 220, 36]
